# %%
# install lerobot
# !pip install lerobot

# Load an existing LeRobot dataset to study structure
from lerobot.datasets.lerobot_dataset import LeRobotDataset

# Load a small example dataset (ALOHA or similar)
dataset = LeRobotDataset(
    "lerobot/aloha_sim_insertion_human",
    video_backend=None  # Skip videos for now
)

sample = dataset[0]
print(sample.keys())
# Out:
# ...
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[9], line 13
#       7 # Load a small example dataset (ALOHA or similar)
#       8 dataset = LeRobotDataset(
#       9     "lerobot/aloha_sim_insertion_human",
#      10     video_backend=None  # Skip videos for now
#      11 )
# ---> 13 sample = dataset[0]
#      14 print(sample.keys())
#
# File ~/Documents/ai/ego2robot/venv-3.11/lib/python3.11/site-packages/lerobot/datasets/lerobot_dataset.py:1015, in LeRobotDataset.__getitem__(self, idx)
#    1013     current_ts = item["timestamp"].item()
#    1014     query_timestamps = self._get_query_timestamps(current_ts, query_indices)
# -> 1015     video_frames = self._query_videos(query_timestamps, ep_idx)
#    1016     item = {**video_frames, **item}
#    1018 if self.image_transforms is not None:
#
# ...

# %%
# Access first sample
sample = dataset[0]
print(f"\nSample keys: {sample.keys()}")
print(f"Observation keys: {list(sample['observation'].keys())}")
print(f"Action shape: {sample['action'].shape}")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[7], line 2
#       1 # Access first sample
# ----> 2 sample = dataset[0]
#       3 print(f"\nSample keys: {sample.keys()}")
#       4 print(f"Observation keys: {list(sample['observation'].keys())}")
#
# File ~/Documents/ai/ego2robot/venv-3.11/lib/python3.11/site-packages/lerobot/datasets/lerobot_dataset.py:1015, in LeRobotDataset.__getitem__(self, idx)
#    1013     current_ts = item["timestamp"].item()
#    1014     query_timestamps = self._get_query_timestamps(current_ts, query_indices)
# -> 1015     video_frames = self._query_videos(query_timestamps, ep_idx)
#    1016     item = {**video_frames, **item}
#    1018 if self.image_transforms is not None:
#
# ...
